# %% [markdown]
# <a href="https://colab.research.google.com/github/lazeicoder/Data-Science-/blob/master/Deep_Learning/Perceptron/Backpropagation_Keras_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.DataFrame([[8,8,4],[7,9,5],[6,10,6],[5,12,7]],columns=['cgpa','profile_score','lpa'])

# %%
print(data)
# Out:
#    cgpa  profile_score  lpa
# 0     8              8    4
# 1     7              9    5
# 2     6             10    6
# 3     5             12    7

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

# Hidden layer
model.add(Dense(2,activation='linear',input_dim=2))
# Output layer
model.add(Dense(1,activation='linear'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.get_weights()
# Out:
# [array([[-0.17984891,  1.1559261 ],
#         [-0.4228413 ,  0.28860366]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.77081496],
#         [ 0.95972955]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
new_weights = [np.array([[0.1,0.1],[0.1,0.1]], dtype=np.float32),
               np.array([0.,0.], dtype=np.float32),
               np.array([[0.1],[0.1]], dtype=np.float32),
               np.array([0.], dtype=np.float32)]

# %%
model.set_weights(new_weights)

# %%
model.get_weights()
# Out:
# [array([[0.1, 0.1],
#         [0.1, 0.1]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.1],
#         [0.1]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mean_squared_error',optimizer=optimizer)

# %%
model.fit(data.iloc[:,0:-1].values, data['lpa'].values, epochs=75, verbose=1, batch_size=1)
# Out:
# Epoch 1/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 24.9470
# Epoch 2/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.6493
# Epoch 3/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.8186
# Epoch 4/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.0326
# Epoch 5/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.7418
# Epoch 6/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 30.1352
# Epoch 7/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.6828
# Epoch 8/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.1219
# Epoch 9/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.1755
# Epoch 10/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.3211
# Epoch 11/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.5348
# Epoch 12/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.4471
# Epoch 13/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.0104
# Epoch 14/75
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.5690
# Epoch 15/75
# ...

# %%
model.get_weights()
# Out:
# [array([[0.37351692, 0.37351692],
#         [0.3655577 , 0.3655577 ]], dtype=float32),
#  array([0.27226517, 0.27226517], dtype=float32),
#  array([[0.3728656],
#         [0.3728656]], dtype=float32),
#  array([0.20486489], dtype=float32)]
